# %%
time_adam = [17.49, 17.11, 21.33, 19.70, 15.96, 18.32, 14.03, 19.24, 16.12, 20.04]
time_powell = [55.73,45.05,70.95,70.95,67.57,47.46,47.37,76.17,47.24,42.14]
time_nm = [37,46,24,28,38,42,72,33,64,68]

fe_adam = [134,168,149,122,142,107,147,122,159,137]
fe_powell = [711,1072,1097,1115,741,728,1145,742,637,868]
fe_nm = [576, 710, 374, 435, 589, 624, 940,432, 762, 812]

ife_powell = [3,80,79,1,0,3,81,2,76,76]
iter_powell = [3,5,5,5,3,3,5,3,3,4]
ife_nm = [2,1,2,4,4,3,4,5,3,4]
iter_nm = [285, 378, 164, 196, 290, 313, 522, 193, 404, 448]

# Calculate and print means and standard deviations
import numpy as np

print(f"time_adam: mean={np.mean(time_adam):.2f}, std={np.std(time_adam):.2f}")
print(f"time_powell: mean={np.mean(time_powell):.2f}, std={np.std(time_powell):.2f}")
print(f"fe_adam: mean={np.mean(fe_adam):.2f}, std={np.std(fe_adam):.2f}")
print(f"fe_powell: mean={np.mean(fe_powell):.2f}, std={np.std(fe_powell):.2f}")
print(f"ife_powell: mean={np.mean(ife_powell):.2f}, std={np.std(ife_powell):.2f}")
print(f"iter_powell: mean={np.mean(iter_powell):.2f}, std={np.std(iter_powell):.2f}")

print(f"ife_nm: mean={np.mean(ife_nm):.2f}, std={np.std(ife_nm):.2f}")
print(f"iter_nm: mean={np.mean(iter_nm):.2f}, std={np.std(iter_nm):.2f}")
print(f"fe_nm: mean={np.mean(fe_nm):.2f}, std={np.std(fe_nm):.2f}")
print(f"time_nm: mean={np.mean(time_nm):.2f}, std={np.std(time_nm):.2f}")
# Out:
# time_adam: mean=17.93, std=2.10
# time_powell: mean=57.06, std=12.30
# fe_adam: mean=138.70, std=17.45
# fe_powell: mean=885.60, std=189.29
# ife_powell: mean=40.10, std=38.34
# iter_powell: mean=3.90, std=0.94
# ife_nm: mean=3.20, std=1.17
# iter_nm: mean=319.30, std=112.08
# fe_nm: mean=625.40, std=173.27
# time_nm: mean=45.20, std=16.17
